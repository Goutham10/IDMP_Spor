# %%
import requests

class Idmp_spor:

    @staticmethod
    def login_api():
        pass

    @staticmethod
    def fetch_data():
        main_id_lists = ["100000000001", "200000000009", "200000000008"] # replace this with the required list ids array from the db
        main_id_lists = ["200000000007"] # replace this with the required list ids array from the db

        auth_token='eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsIng1dCI6ImJJZDNaTjdNemU0OXZqTjZ3U0ZUZS00LUxxSSIsImtpZCI6Im9yYWtleSJ9.....RJB_sL5UaB6F2H2inOtbjsGvPSryv5GKeNKZl5jcqd9iznIROb5_7l2HtM_I7VvdgJ-LD3bsZdnla9dapPo8dEbsOkW2Bbt3Q68Fq5Qt582ozNecnXzYsd7TDvMOwUHB9qE788N_1e_r7WWPLBl03MkGrWzYfjjMetEBM3fhVtA'
        header = {
            'accept' : "application/json",
            'Authorization': 'Bearer ' + auth_token
        }

        main_dict = {}

        for main_id in main_id_lists:
            url = f'https://spor.ema.europa.eu/v1/lists/{main_id}/term-summaries?lang=en&page=1&pagesize=20&parent=all&sortby=term-name'
            response = requests.get(url,  headers=header)
        #     print(response)
            data = response.json()
            main_list = []
            sub_list = []
            while url != "":
                spor_list = []
                try:
                    response = requests.get(url,  headers=header)
                    
                    data = response.json()

                    itemlist = data['controlled-terms-list-summary']['controlled-term-summaries']["controlled-term-summary"]
                
                    for i in range(len(itemlist)):

                        dict_val = {}

                        list_name = data['controlled-terms-list-summary']['list-summary']['list-name']

                        id = itemlist[i]["term-id"]["id"] 
                        term_name = itemlist[i]["term-names"]["term-name"]["name"]["text"]

                        if "short-names" not in  itemlist[i].keys():
                            short_name = ""
                        else:
                            short_name=itemlist[i]["short-names"]["short-name"]["name"]["text"]

                        source_id = ""

                        status = itemlist[i]["status"]["code"]

                        dict_val["id"] = id
                        dict_val["term-name"] = term_name
                        dict_val["short-name"] = short_name
                        dict_val["source_id"] = source_id
                        dict_val["status"] = status

                        spor_list.append(dict_val)
                except Exception as e:
                    print()
                sub_list.append(spor_list)
                main_list.extend(sub_list)

                nextpage = data["controlled-terms-list-summary"]["next-page"]
                url = nextpage
                main_dict[list_name] = main_list

        # print(main_dict)

        for list_item, value in main_dict.items():
            print(list_item, ":", value)
            print()
            

idmp_spor = Idmp_spor()
idmp_spor.fetch_data()
# Out:
# Age Range : [[{'id': '100000000034', 'term-name': 'Adolescents (12 to < 18 years)', 'short-name': 'Adolescents', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002250', 'term-name': 'Adult and elderly population (>18 years)', 'short-name': 'Adults and elderly', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000000327', 'term-name': 'Adult animal', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000000035', 'term-name': 'Adults (18 to < 65 years)', 'short-name': 'Adults', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000000326', 'term-name': 'All', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000000033', 'term-name': 'Children (2 to < 12 years)', 'short-name': 'Children', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000000331', 'term-name': 'Egg', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000000036', 'term-name': 'Elderly (≥ 65 years)', 'short-name': 'Elderly', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000000329', 'term-name': 'Embryonated egg', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000000029', 'term-name': 'In utero', 'short-name': 'In utero', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000000032', 'term-name': 'Infants and toddlers (28 days – 23 months)', 'short-name': 'Infants and toddlers', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000000037', 'term-name': 'Neonate', 'short-name': 'Neonate', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000072071', 'term-name': 'Paediatric Population (< 18 years)', 'short-name': 'Paediatric Population', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002249', 'term-name': 'Prepubertal children (2 years to onset of puberty)', 'short-name': 'Prepubertal children', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000000030', 'term-name': 'Preterm newborn infants (0 – 27 days)', 'short-name': 'Preterm newborn infants', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002251', 'term-name': 'Pubertal and postpubertal adolescents (onset of puberty to < 18 years)', 'short-name': 'Pubertal and postpubertal adolescents', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000000031', 'term-name': 'Term newborn infants (0 – 27 days)', 'short-name': 'Term newborn infants', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000000328', 'term-name': 'Young animal', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000000330', 'term-name': 'Young animal/Newborn', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}]]
#
# Basic Dose Form : [[{'id': '200000002013', 'term-name': 'Additive (unspecified)', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002082', 'term-name': 'Block', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002083', 'term-name': 'Cachet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002084', 'term-name': 'Capsule', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002027', 'term-name': 'Cement', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002001', 'term-name': 'Collodion', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002002', 'term-name': 'Concentrate', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002104', 'term-name': 'Cream', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002003', 'term-name': 'Dispersion', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002014', 'term-name': 'Drops (unspecified)', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002004', 'term-name': 'Emulsion', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002085', 'term-name': 'Film', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002105', 'term-name': 'Foam', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002106', 'term-name': 'Gel', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002086', 'term-name': 'Granules', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002087', 'term-name': 'Gum', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000003234', 'term-name': 'Herbal material (unprocessed)', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002088', 'term-name': 'Implant', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002089', 'term-name': 'Impregnated material', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002012', 'term-name': 'Insert', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}], [{'id': '200000002013', 'term-name': 'Additive (unspecified)', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002082', 'term-name': 'Block', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002083', 'term-name': 'Cachet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002084', 'term-name': 'Capsule', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002027', 'term-name': 'Cement', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002001', 'term-name': 'Collodion', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002002', 'term-name': 'Concentrate', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002104', 'term-name': 'Cream', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002003', 'term-name': 'Dispersion', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002014', 'term-name': 'Drops (unspecified)', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002004', 'term-name': 'Emulsion', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002085', 'term-name': 'Film', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002105', 'term-name': 'Foam', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002106', 'term-name': 'Gel', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002086', 'term-name': 'Granules', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002087', 'term-name': 'Gum', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000003234', 'term-name': 'Herbal material (unprocessed)', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002088', 'term-name': 'I ...
#
# Combination Package : [[{'id': '200000003176', 'term-name': 'Capsule, hard + tablet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000003175', 'term-name': 'Capsule, soft + tablet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000173972', 'term-name': 'Cream + pessary', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000173980', 'term-name': 'Cream + vaginal capsule, soft', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000173981', 'term-name': 'Cream + vaginal tablet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000173973', 'term-name': 'Cutaneous solution + medicated sponge', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000173977', 'term-name': 'Effervescent granules + film-coated tablet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000015757', 'term-name': 'Effervescent granules + gastro-resistant tablet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000173978', 'term-name': 'Effervescent tablet + film-coated tablet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002334', 'term-name': 'Film-coated tablet + pessary', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000003177', 'term-name': 'Film-coated tablet + tablet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000173974', 'term-name': 'Gastro-resistant tablet + rectal suspension', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000010779', 'term-name': 'Ointment + vaginal tablet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000173979', 'term-name': 'Tablet + vaginal tablet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000173975', 'term-name': 'Vaginal capsule, soft + vaginal cream', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000173976', 'term-name': 'Vaginal cream + vaginal tablet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}]]
