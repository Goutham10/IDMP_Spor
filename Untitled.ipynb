# %%
import requests

class Idmp_spor:

    @staticmethod
    def login_api():
        pass

    @staticmethod
    def fetch_data():
#         main_id_lists = ["100000000001", "200000000009", "200000000008"] # replace this with the required list ids array from the db
        main_id_lists = ["200000000007"] # replace this with the required list ids array from the db

        auth_token='eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsIng1dCI6ImJJZDNaTjdNemU0OXZqTjZ3U0ZUZS00LUxxSSIsImtpZCI6Im9yYWtleSJ9.....RJB_sL5UaB6F2H2inOtbjsGvPSryv5GKeNKZl5jcqd9iznIROb5_7l2HtM_I7VvdgJ-LD3bsZdnla9dapPo8dEbsOkW2Bbt3Q68Fq5Qt582ozNecnXzYsd7TDvMOwUHB9qE788N_1e_r7WWPLBl03MkGrWzYfjjMetEBM3fhVtA'
        header = {
            'accept' : "application/json",
            'Authorization': 'Bearer ' + auth_token
        }

        main_dict = {}

        for main_id in main_id_lists:
            url = f'https://spor.ema.europa.eu/v1/lists/{main_id}/term-summaries?lang=en&page=1&pagesize=20&parent=all&sortby=term-name'
            response = requests.get(url,  headers=header)
        #     print(response)
            data = response.json()
            main_list = []
            sub_list = []
            while url != "":
                spor_list = []
                try:
                    response = requests.get(url,  headers=header)
                    
                    data = response.json()

                    itemlist = data['controlled-terms-list-summary']['controlled-term-summaries']["controlled-term-summary"]
                
                    for i in range(len(itemlist)):

                        dict_val = {}

                        list_name = data['controlled-terms-list-summary']['list-summary']['list-name']

                        id = itemlist[i]["term-id"]["id"] 
                        term_name = itemlist[i]["term-names"]["term-name"]["name"]["text"]

                        if "short-names" not in  itemlist[i].keys():
                            short_name = ""
                        else:
                            short_name=itemlist[i]["short-names"]["short-name"]["name"]["text"]

                        source_id = ""

                        status = itemlist[i]["status"]["code"]

                        dict_val["id"] = id
                        dict_val["term-name"] = term_name
                        dict_val["short-name"] = short_name
                        dict_val["source_id"] = source_id
                        dict_val["status"] = status

                        spor_list.append(dict_val)
                except Exception as e:
                    print()
                sub_list.extend(spor_list)
                main_list.extend(sub_list)

                nextpage = data["controlled-terms-list-summary"]["next-page"]
                url = nextpage
                main_dict[list_name] = main_list

        # print(main_dict)

        for list_item, value in main_dict.items():
            print(list_item, ":", value)
            print()
            

idmp_spor = Idmp_spor()
idmp_spor.fetch_data()
# Out:
# Combined Term : [{'id': '100000170490', 'term-name': 'Bee-hive dispersion in sachet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000116144', 'term-name': 'Coated granules in sachet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002380', 'term-name': 'Cutaneous solution in single-dose container', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000156090', 'term-name': 'Ear drops, solution in single-dose container', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000125738', 'term-name': 'Ear drops, suspension in single-dose container', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000172025', 'term-name': 'Emulsion for infusion in administration system', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000125739', 'term-name': 'Emulsion for injection/infusion in pre-filled syringe', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002333', 'term-name': 'Eye drops, emulsion in single-dose container', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000136320', 'term-name': 'Eye drops, prolonged-release solution in single-dose container', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000073997', 'term-name': 'Eye drops, solution in single-dose container', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000136321', 'term-name': 'Eye drops, suspension in single-dose container', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000125740', 'term-name': 'Eye gel in single-dose container', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000136322', 'term-name': 'Eye ointment in single-dose container', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000156069', 'term-name': 'Film-coated tablet and gastro-resistant granules in sachet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000125741', 'term-name': 'Gastro-resistant granules for oral suspension in sachet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000125712', 'term-name': 'Gel in pressurised container', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000174060', 'term-name': 'Gel in sachet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000136323', 'term-name': 'Granules for oral solution in sachet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000125742', 'term-name': 'Granules for oral suspension in sachet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000003542', 'term-name': 'Granules in capsule for opening', 'short-name': '', 'source_id': '', 'status': 'NON_CURRENT'}, {'id': '100000170490', 'term-name': 'Bee-hive dispersion in sachet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000116144', 'term-name': 'Coated granules in sachet', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002380', 'term-name': 'Cutaneous solution in single-dose container', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000156090', 'term-name': 'Ear drops, solution in single-dose container', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000125738', 'term-name': 'Ear drops, suspension in single-dose container', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000172025', 'term-name': 'Emulsion for infusion in administration system', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000125739', 'term-name': 'Emulsion for injection/infusion in pre-filled syringe', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '200000002333', 'term-name': 'Eye drops, emulsion in single-dose container', 'short-name': '', 'source_id': '', 'status': 'CURRENT'}, {'id': '100000136320', 'term-name': 'Eye drops, prolonged-release solution in single-dose container', 'short-name': '', 'so ...

# %%
import mysql.connector

mydb = mysql.connector.connect(host="127.0.0.1", 
                               port="3306", 
                               user="root", 
                               password="Goutham@1005", 
                               auth_plugin="mysql_native_password", 
                               database="persons_db")

print(mydb)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       1 import mysql.connector
# ----> 3 mydb = mysql.connector.connect(host="127.0.0.1",
#       4                                port="3306",
#       5                                user="root",
#       6                                password="Goutham@1005",
#       7                                auth_plugin="mysql_native_password",
#       8                                database="persons_db")
#      10 print(mydb)
#
# File /usr/local/lib/python3.8/dist-packages/mysql/connector/__init__.py:272, in connect(*args, **kwargs)
#     269         raise ImportError(ERROR_NO_CEXT)
#     271 if HAVE_CEXT and not use_pure:
# --> 272     return CMySQLConnection(*args, **kwargs)
#     273 return MySQLConnection(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/mysql/connector/connection_cext.py:94, in CMySQLConnection.__init__(self, **kwargs)
#      91 super(CMySQLConnection, self).__init__(**kwargs)
#      93 if kwargs:
# ---> 94     self.connect(**kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/mysql/connector/abstracts.py:1052, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1049     self.config(**kwargs)
#    1051 self.disconnect()
# -> 1052 self._open_connection()
#    1053 # Server does not allow to run any other statement different from ALTER
#    1054 # when user's password has been expired.
#    1055 if not self._client_flags & ClientFlag.CAN_HANDLE_EXPIRED_PASSWORDS:
#
# File /usr/local/lib/python3.8/dist-packages/mysql/connector/connection_cext.py:246, in CMySQLConnection._open_connection(self)
#     232     cnx_kwargs.update({
#     233         'ssl_ca': self._ssl.get('ca'),
#     234         'ssl_cert': self._ssl.get('cert'),
#    (...)
#     242         'ssl_disabled': self._ssl_disabled
#     243     })
#     245 try:
# --> 246     self._cmysql.connect(**cnx_kwargs)
#     247     self._cmysql.converter_str_fallback = self._converter_str_fallback
#     248     if self.converter:
#
# TypeError: function takes at most 24 keyword arguments (25 given)
